# %% [markdown]
# # Hierarchical clustering

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#data
X = np.array([[5,3], [10,15], [15,12], [24,10], [30,30], [85,70], [71,80], [60,78], [70,55], [80,91],])

# %%
import matplotlib.pyplot as plt
labels = range(1,11)
plt.figure(figsize=(10,7))
plt.scatter(X[:,0], X[:,1])

# Python’s zip() function is defined as zip(*iterables)
for label, x, y in zip(labels, X[:, 0], X[:, 1]):
    # annotate the point xy with text label
    plt.annotate(
        label,
        xy=(x, y), xytext=(-3, 3),
        textcoords='offset points', ha='right', va='bottom')
plt.show()

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
linked = linkage(X, 'single') #using single link for distance btw clusters
labelList = range(1,11)
plt.figure(figsize=(10,7))
dendrogram(linked, orientation='top', labels=labelList, 
           distance_sort='descending', show_leaf_counts=True)
plt.show()

# %%
#using practical data
customer_data = pd.read_csv('./Data/shopping-data.csv')
customer_data.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
data = customer_data.iloc[:,3:5].values #using annual income & spending score

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10,7))
dend=shc.dendrogram(shc.linkage(data, method='ward')) #using ward's distance
